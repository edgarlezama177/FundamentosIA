# %% [markdown]
# ## Laboratorio 3 : Proposiciones
#
# ### Fecha 7 de Septiembre

# %% [markdown]
# Proposiciones:
#
# P: Se encuentra dentro del rango
# Q: El nivel es suficiente
# R: Existe municiones disponibles
# S: Esta visible
# T: No existe amenaza cercana
# U: No esta aturdido

# %%
### Definición de variables
rango = True #Si esta dentro del rango
nivelVida=True #Tiene vida suficiente
municion=False #Si cuenta con municiones disponibles
visible=True #Si esta visible el jugador
amenaza=False #No existe amenaza cercana
aturdido=False #No esta aturdido

# %%
puedeAtacar= (rango==True and visible==True and nivelVida==True and municion==True and amenaza==True and aturdido==False)

# %%
print("El agente enemigo puede atacar?", puedeAtacar)
# Out:
# El agente enemigo puede atacar? False

# %%
print(" == Agente Enemigo Inteligente == ")
print("Development by Edgar")

rango = input("El jugador se encuentra dentro del rango (s/n): ").lower() =="s"
#print(rango)
visible = input("El jugador esta visible (s/n): ").lower() == "s"
#print(visible)
nivelVida = input("Tienes suficiente vida (s/n): ").lower() == "s"
#print(nivelVida)
municiones = input("El enemigo tiene suficientes municiones (s/n): ").lower() == "s"
#print(municiones)
amenaza = input("Existe una amenaza cercana? (s/n): ").lower() == "n"
#print(amenaza)
aturdido = input("El enemigo esta aturdido? (s/n): ").lower() == "n"
#print(aturdido)

puedeAtacar= (rango and visible and nivelVida and municiones and amenaza and aturdido)

print ("Decisión del agente")
if puedeAtacar == True:
    print("El agente puede atacar: Es tu momento!!!!!")
else:
    print("Escondete!!! No es momento de atacar")
# Out:
#  == Agente Enemigo Inteligente ==
# Development by Edgar
# El jugador se encuentra dentro del rango (s/n):  s
# El jugador esta visible (s/n):  s
# Tienes suficiente vida (s/n):  s
# El enemigo tiene suficientes municiones (s/n):  s
# Existe una amenaza cercana? (s/n):  n
# El enemigo esta aturdido? (s/n):  n
# Decisión del agente
# El agente puede atacar: Es tu momento!!!!!
