# %%
print ("Sistema de riego para plantas")

planta=input("Escriba el nombre de la planta")
humedad=float(input("Escriba el porcentaje de humedad"))

print("DATOS ALMACENADOS")
print("Planta: ", planta)
print("Humedad: ", humedad)
# Out:
# Sistema de riego para plantas
# Escriba el nombre de la planta Rosa
# Escriba el porcentaje de humedad 34
# DATOS ALMACENADOS
# Planta:  Rosa
# Humedad:  34.0

# %%
if humedad < 40:
    print("La planta necesita riego")
elif humedad >= 40:
    print("No necesita riego")
# Out:
# La planta necesita riego
