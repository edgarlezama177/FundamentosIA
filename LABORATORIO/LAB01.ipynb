# %% [markdown]
# ## LABORATORIO 01
# # 01/09/2026
# # EDGAR GONZALEZ LEZAMA

# %%
print ("Primer sistema Inteligente")
nombre=input("Escriba su nombre empezando por apellido paterno")
matricula=input("Escriba su matrícula")
promedio=float(input("Escriba su promedio"))

print("Datos Almacenados")
print("Nombre: ", nombre)
print("Matricula: ",matricula)
print("Promedio: ",promedio)
# Out:
# Primer sistema Inteligente
# Escriba su nombre empezando por apellido paterno Lezama Edgar
# Escriba su matrícula 20220202
# Escriba su promedio 5.6
# Datos Almacenados
# Nombre:  Lezama Edgar
# Matricula:  20220202
# Promedio:  5.6

# %% [markdown]
# REGLAS

# %%
if promedio>=8.0 and promedio<=10:
    print("Excelente promedio")
elif promedio<8 and promedio >=7:
    print("Échale ganas, puedes mejorar")
else: 
    print("Reprobaste, tienes que hacer recursa")
# Out:
# Reprobaste, tienes que hacer recursa
