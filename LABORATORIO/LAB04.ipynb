# %% [markdown]
# Laboratorio 4

# %% [markdown]
# P: El servidor principal no está disponible
# Q: La latencia supera el límite establecido
# R: La pérdida de paquetes supera el límite permitido
# S: El tráfico de red es anormalmente alto
# T: El servidor de respaldo no está disponible
# U: El sistema de monitoreo está activo

# %%
servidorPrincipal=False
latencia=True
perdidaPaquetes=True
traficoAlto=True
servidorRespaldo=False
monitoreo=True

# %%
condicionCritica= (servidorPrincipal == False and latencia == True and perdidaPaquetes == True and traficoAlto == True and servidorRespaldo == False and monitoreo == True)

# %%
print("Existe una condición crítica de servicio? ", condicionCritica)
# Out:
# Existe una condición crítica de servicio?  True

# %%
print("== Sistema Inteligente de Red ==")
print("Development by Edgar")

servidorPrincipal = input ("El servidor principal no está disponible? (s/n): ").lower()=="s"
latencia = input ("La latencia supera el límite establecido? (s/n): ").lower()=="s"
perdidaPaquetes = input ("La pérdida de paquetes supera el límite permitido? (s/n): ").lower()=="s"
traficoAlto = input ("El tráfico de red es anormalmente alto (s/n): ").lower()=="s"
servidorRespaldo = input ("El servidor de respaldo no está disponible? (s/n): ").lower()=="s"
monitoreo = input ("El sistema de monitoreo está activo? (s/n): ").lower()=="s"

condicionCritica= (servidorPrincipal == False and latencia == True and perdidaPaquetes == True and traficoAlto == True and servidorRespaldo == False and monitoreo == True)

print("Decisión del sistema")
if condicionCritica == True:
    print("Existe una condición crítica de servicio")
else:
    print("No existe una condición crítica de servicio")
# Out:
# == Sistema Inteligente de Red ==
# Development by Edgar
# El servidor principal no está disponible? (s/n):  n
# La latencia supera el límite establecido? (s/n):  s
# La pérdida de paquetes supera el límite permitido? (s/n):  s
# El tráfico de red es anormalmente alto (s/n):  s
# El servidor de respaldo no está disponible? (s/n):  n
# El sistema de monitoreo está activo? (s/n):  s
# Decisión del sistema
# Existe una condición crítica de servicio
